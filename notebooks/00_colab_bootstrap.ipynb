# %% [markdown]
# 환경 세팅입니다. MACOS를 기준으로 init되었기에, 실행이 제대로 되지 않는닥 하시면 카톡으로 공유 부탁드립니다.

# %%
# python version check

import sys

# 3.7 ~ 3.11 사이의 python 설치를 부탁합니다.
#print(sys.version_info)
assert sys.version_info >= (3, 7)
# Out:
# sys.version_info(major=3, minor=11, micro=14, releaselevel='final', serial=0)

# %%
# sklearn version check

from packaging import version
import sklearn

assert version.parse(sklearn.__version__) >= version.parse("1.0.1")

# %%
# numpy and tensorflow, GPU CPU check

import numpy as np, tensorflow as tf
print("NumPy:", np.__version__)
print("TF:", tf.__version__)
print("Devices:", tf.config.list_physical_devices())
# Out:
# NumPy: 1.26.4
# TF: 2.16.2
# Devices: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
